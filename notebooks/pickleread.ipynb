# %%
import pickle

# %%
with open('./data/tracker_META_20241106.pkl', 'r+b') as f:
    data = pickle.load(f)

# %%
data
# Out:
# {'symbol': 'META',
# ...

# %%
data['trade_list']
# Out:
# [Trade(contract=Stock(symbol='META', exchange='SMART', currency='USD'), order=LimitOrder(orderId=115, clientId=27, permId=312863313, action='SELL', totalQuantity=200.0, lmtPrice=561.39, auxPrice=0.0), orderStatus=OrderStatus(orderId=115, status='Filled', filled=200.0, remaining=0.0, avgFillPrice=561.42, permId=312863313, parentId=0, lastFillPrice=561.42, clientId=27, whyHeld='', mktCapPrice=0.0), fills=[Fill(contract=Stock(conId=107113386, symbol='META', exchange='NASDAQ', currency='USD', localSymbol='META', tradingClass='NMS'), execution=Execution(execId='00025b45.672b4790.01.01', time=datetime.datetime(2024, 11, 6, 15, 8, 37, tzinfo=datetime.timezone.utc), acctNumber='DU9749485', exchange='NASDAQ', side='SLD', shares=100.0, price=561.42, permId=312863313, clientId=27, orderId=115, liquidation=0, cumQty=100.0, avgPrice=561.42, orderRef='', evRule='', evMultiplier=0.0, modelCode='', lastLiquidity=2, pendingPriceRevision=False), commissionReport=CommissionReport(execId='00025b45.672b4
# ...
